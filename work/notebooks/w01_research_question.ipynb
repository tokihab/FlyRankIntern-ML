# %%
import os, sys, subprocess

# Clone your specific repository into Colab
IN_COLAB = "google.colab" in sys.modules
REPO_URL = "https://github.com/tokihab/FlyRank-ML" # Your repo URL
REPO_DIR = "FlyRank-ML"

if IN_COLAB:
    if not os.path.isdir(REPO_DIR):
        subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)
    os.chdir(REPO_DIR)

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/tokihab/FlyRank-ML/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# Lane 3: Structured Content Archetype Clustering.
#
# I will find common page patterns by grouping them based on their stats (like word counts and traffic) rather than reading the text. Using basic grouping algorithms, I can automatically spot page types, like "short but popular." Because the dataset has no raw text, I will not group pages by their topic or meaning.

# %%
# Check total volume available for clustering
print(f"Total pages available for archetype clustering: {len(df)}")
print("Potential clustering features:", ["word_count", "impressions_90d", "avg_position", "ctr"])
# Out:
# Total pages available for archetype clustering: 30000
# Potential clustering features: ['word_count', 'impressions_90d', 'avg_position', 'ctr']

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
# Decision:-
#
# =What is the right fix for a failing page?
#
# Action:-
#
# =Editors will use these groups to decide if a page should be updated, rewritten, combined, or deleted.
#
# Cost of a wrong call:-
#
#  =Wasting hours on the wrong fix, like ordering a complex technical review when a page just needed a few more paragraphs.

# %%
# Check how many pages fall into potential rewrite or update action buckets
stale_pages = df["days_since_last_update"] >= 180
print(f"Pages not updated in 180+ days (update/rewrite candidates): {stale_pages.sum()}")
# Out:
# Pages not updated in 180+ days (update/rewrite candidates): 174

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

# 1. How many pages are short but still get traffic?
thin_visible = df[(df["word_count"] > 0) & (df["word_count"] < 1200) & (df["impressions_90d"] >= 250)]
print(f"Short, visible pages: {len(thin_visible)}")

# 2. What are the main types of pages we can group?
print("\nTop page types:")
print(df["content_type"].value_counts().head(4).to_string())
# Out:
# Short, visible pages: 82
#
# Top page types:
# content_type
# keyword article       27207
# feedly article         2096
# comparison article      697

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
# I will report observed page groups to provide decision-support for editors.
#
# I will not claim to group pages by their actual text meaning. I will also never claim causal proof (promising that my suggested fix guarantees more traffic).

# %%
# Summary check to verify we are only using observable metrics
print("Summary of key observable signals:")
print(df[["impressions_90d", "word_count", "avg_position"]].describe().round(1).to_string())
# Out:
# Summary of key observable signals:
#        impressions_90d  word_count  avg_position
# count          30000.0     22301.0       30000.0
# mean            5200.4      3107.8          16.3
# std            16838.0      1452.4          15.2
# min                1.0         8.0           0.0
# 25%               81.0      2413.0           6.2
# 50%              731.0      2877.0          10.8
# 75%             3615.2      3666.0          22.3
# max           517715.0      9546.0         245.0

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
